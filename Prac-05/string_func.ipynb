# %%
# Program to demonstrate various operations
# of string in python 
s1="python in VSCode"
s2="ALL UPPERCASE"
s3="all lowercase"
s4="py:thon in V:S:Code"
s5='             python   in jupyter notebook        '
s6='line1 \n line2 \n line3 \n line4'

#1
a = s1.find('C')
print('#1')
print(a,"\n")

#2
print('#2')
b1 = s1.isupper()
print(b1)
b2 = s2.isupper()
print(b2)
b3 = s3.islower()
print(b3,"\n")

#3
print('#3')
c=s1.replace("VSCode","Pycharm")
print(c,"\n")

#4
print('#4')
d1=s1.split()
print(d1)
d2=s4.split(":")
print(d2)
d3=s3.splitlines()
print(s6,"\n")

#5
print('#5')
e=s1.title()
print(e)
f=s1.capitalize()
print(f)
g=s1.casefold()
print(g,"\n")

#6
print('#6')
h=s1.count("o")
print(h,"\n")

#7
print('#7')
print(f'{s1.center(20)}\n')

#8
print('#8')
print(s5,'\n',s5.strip())
# Out:
# #1
# 12
#
# #2
# False
# True
# True
#
# #3
# python in Pycharm
#
# #4
# ['python', 'in', 'VSCode']
# ['py', 'thon in V', 'S', 'Code']
# line1
#  line2
#  line3
#  line4
#
# #5
# Python In Vscode
# Python in vscode
# python in vscode
#
# #6
# 2
#
# #7
#   python in VSCode
#
# #8
#              python   in jupyter notebook
#  python   in jupyter notebook
